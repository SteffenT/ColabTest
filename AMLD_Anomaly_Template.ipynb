# %% [markdown]
# <a href="https://colab.research.google.com/github/SteffenT/ColabTest/blob/master/AMLD_Anomaly_Template.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import prepared train and test data
# This only needs to be done once per notebook.
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# Authenticate and create the PyDrive client.
# This only needs to be done once per notebook.
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# Download data files from google drive
file_id = '1wsUehLalIqHluiAfkDAKD8AUw70Ooqv_'
downloaded = drive.CreateFile({'id': file_id})
downloaded.GetContentFile('y_train.pkl')
file_id = '1IvxnZrPw8hA_3MGjCvyd67A4MbL-C3Fc'
downloaded = drive.CreateFile({'id': file_id})
downloaded.GetContentFile('y_test.pkl')
file_id = '14X4QeOEUbUaRggNnBxr9QVW5FeYmQ2ni'
downloaded = drive.CreateFile({'id': file_id})
downloaded.GetContentFile('x_train.pkl')
file_id = '12dQl3ONETA7lslVCVOF5SXqqESQYyntV'
downloaded = drive.CreateFile({'id': file_id})
downloaded.GetContentFile('x_test.pkl')

file_id = '1OE9OaybAx5aiSwlz7pcmc0y8DUDQ0DO_'
downloaded = drive.CreateFile({'id': file_id})
downloaded.GetContentFile('trax_features.pkl')
file_id = '1MeEpVedHTjJRvV27g6BqstnUV6M2k-SN'
downloaded = drive.CreateFile({'id': file_id})
downloaded.GetContentFile('DataPreparation.ipynb')

# %%
# all from Ernesto

import os
import gc
import pickle
import pandas as pd
import sklearn
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.ensemble import IsolationForest
from sklearn.model_selection import StratifiedKFold
import lightgbm as lgb

# %matplotlib inline
from sklearn.ensemble import IsolationForest, RandomForestClassifier
from sklearn.linear_model import LogisticRegression, LogisticRegressionCV
from sklearn.preprocessing import LabelEncoder
import numpy as np
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import train_test_split

# %%
x_train = pd.read_pickle('x_train.pkl')
y_train = pd.read_pickle('y_train.pkl')
x_test = pd.read_pickle('x_test.pkl')
y_test = pd.read_pickle('y_test.pkl')

# %%
x_train
# Out:
#         TransactionAmt  ProductCD  ...  R_emaildomain_bin  R_emaildomain_suffix
# 5485              40.0          4  ...                  6                     6
# 52399             29.0          4  ...                  6                     6
# 116477           250.0          2  ...                  4                     0
# 138959            59.0          4  ...                  6                     6
# 56635             20.0          1  ...                  6                     6
# ...                ...        ...  ...                ...                   ...
# 121974           117.0          4  ...                  6                     6
# 124605           295.0          4  ...                  6                     6
# 20463            313.0          4  ...                  6                     6
# 18638           1284.0          4  ...                  6                     6
# 35683            100.0          1  ...                  6                     6
#
# ...
